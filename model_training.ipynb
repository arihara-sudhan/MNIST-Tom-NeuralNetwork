# %% [markdown]
# # IMPORTING MODULES

# %%
import torch
from torch import nn
from torch import optim
from torchvision import datasets, transforms
from torch.utils.data import random_split, DataLoader
import matplotlib.pyplot as plt
from PIL import Image
import numpy

# %% [markdown]
# # MY FIRST MODEL

# %%
model = nn.Sequential(
    nn.Linear(28*28,64),
    nn.ReLU(),
    nn.Linear(64,64),
    nn.ReLU(),
    nn.Linear(64,10)
)

# %% [markdown]
# # OPTIMIZER 🚀

# %%
optimiser = optim.SGD(model.parameters(), lr = 1e-2)

# %% [markdown]
# # DEFINING LOSS

# %%
loss = nn.CrossEntropyLoss()

# %% [markdown]
# # SPLITTING THE DATA

# %%
train_data = datasets.MNIST('data', train=True, download=True, transform=transforms.ToTensor())
train,dev = random_split(train_data,[55000,5000])
train_loader = DataLoader(train,batch_size=32)
dev_loader = DataLoader(dev,batch_size=32)

# %% [markdown]
# # EPOCHS || LOOP

# %%
epochs = 12
for epoch in range(epochs):
    losses = list()
    for batch in train_loader:
        x,y = batch
        x = x.view(x.size(0), -1)
        logit = model(x)
        J = loss(logit,y)
        model.zero_grad()
        J.backward()
        optimiser.step()
        losses.append(J.item())
    print(f'@ Epoch = {epoch+1}\nTraining Loss = {torch.tensor(losses).mean():.2f}')
    losses = list()
    for batch in dev_loader:
        x,y = batch
        x = x.view(x.size(0), -1)
        with torch.no_grad():
            logit = model(x)
        J = loss(logit,y)
        losses.append(J.item())
    print(f'Validation Loss = {torch.tensor(losses).mean():.2f}\n--------------------------')
# Out:
# Running cells with 'mnist_tom' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/ari-pt7127/Desktop/Python/mnist_tom/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
torch.save(model,"models/mnist.pt")

# %%
model = torch.load('models/mnist.pt')

# %%
test_set = datasets.MNIST('data', train=False, download=True, transform=transforms.ToTensor())
test_loader = DataLoader(test_set, batch_size=32, shuffle=True)

# %%
correct = 0 ; total = 0
with torch.no_grad():
    for data in test_loader:
        x, y = data
        output = model(x.view(-1, 784))
        for idx, i in enumerate(output):
            if torch.argmax(i) == y[idx]:
                correct +=1
            total +=1
print(f'Accuracy: {round(correct/total, 3)}')
# Out:
# Accuracy: 0.954

# %%
def digit(th):
    return str(int(torch.argmax(model(x[th].view(-1, 784))[0])))

# %%
# Out:
# Running cells with 'mnist_tom' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/ari-pt7127/Desktop/Python/mnist_tom/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
import cv2
th=0
while True:
    frame = numpy.array(transforms.ToPILImage()(x[th]).convert("RGB"))[:, :, ::-1].copy()
    frame = cv2.resize(frame,(900,900))
    cv2.putText(frame, 'DIGIT : '+str(digit(th)), (10,60), cv2.FONT_HERSHEY_SIMPLEX, 2, (0,255,0), 5)
    cv2.imshow('DIGIT',frame)
    k = cv2.waitKey()
    if k==27:
        break
    elif k==110 and th<15:
        th+=1
    elif k==112 and th>0:
        th-=1
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
#
# QObject::moveToThread: Current thread (0x55a57267fc40) is not the object's thread (0x55a572c57e40).
# Cannot move to target thread (0x55a57267fc40)
